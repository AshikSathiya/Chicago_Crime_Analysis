# %% [markdown]
# # Prepare Chicago Crime Data for a GitHub Repository

# %% [markdown]
# - Original Notebook Source: https://github.com/coding-dojo-data-science/preparing-chicago-crime-data
# - Updated 11/17/22

# %% [markdown]
# >- This notebook will process a "Crimes - 2001 to Preset.csv" crime file in your Downloads folder and save it as smaller .csv's in a new "Data/Chicago/" folder inside this notebook's folder/repo.

# %% [markdown]
# # INSTRUCTIONS

# %% [markdown]
# - 1) Go to the Chicago Data Portal's page for ["Crimes - 2001 to Preset"](https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-Present/ijzp-q8t2).
#
# - 2) Click on the Export button on the top right and select CSV.
#     - Save the file to your Downloads folder instead of your repository. **The file is too big for a repository.**
#
#
#
# - 3) Wait for the full file to download.
#     - It is very large (over >1.7GB and may take several minutes to fully download.)
#
#
# - 4) Once the download is complete, change `RAW_FILE` variable below to match the filepath to the downloaded file.

# %% [markdown]
# ## 🚨 Set the correct `RAW_FILE` path

# %% [markdown]
# - The cell below will attempt to check your Downloads folder for any file with a name that contains "Crimes_-_2001_to_Present".
#     - If you know the file path already, you can skip the next cell and just manually set the RAW_FILE variable in the following code cell.

# %%
## Run the cell below to attempt to programmatically find your crime file
import os,glob

## Getting the home folder from environment variables
home_folder = os.environ['HOME']
# print("- Your Home Folder is: " + home_folder)

## Check for downloads folder
if 'Downloads' in os.listdir(home_folder):
    
    
    # Print the Downloads folder path
    dl_folder = os.path.abspath(os.path.join(home_folder,'Downloads'))
    print(f"- Your Downloads folder is '{dl_folder}/'\n")
    
    ## checking for crime files using glob
    crime_files = sorted(glob.glob(dl_folder+'/**/Crimes_-_2001_to_Present*',recursive=True))
    
    # If more than 
    if len(crime_files)==1:
        RAW_FILE = crime_files[0]
        
    elif len(crime_files)>1:
        print('[i] The following files were found:')
        
        for i, fname in enumerate(crime_files):
            print(f"\tcrime_files[{i}] = '{fname}'")
        print(f'\n- Please fill in the RAW_FILE variable in the code cell below with the correct filepath.')

else:
    print(f'[!] Could not programmatically find your downloads folder.')
    print('- Try using Finder (on Mac) or File Explorer (Windows) to navigate to your Downloads folder.')
# Out:
# - Your Downloads folder is '/Users/ashik/Downloads/'

# %% [markdown]
# <span style="color:red"> **IF THE CODE ABOVE DID NOT FIND YOUR DOWNLOADED FILE, UNCOMMENT AND CHANGE THE `"YOUR FILEPATH HERE"` VARIABLE ONLY IN THE CELL BELOW**

# %%
## (Required) MAKE SURE TO CHANGE THIS VARIABLE TO MATCH YOUR LOCAL FILE NAME
##RAW_FILE = r"YOUR FILEPATH HERE")

# %% [markdown]
# <span style="color:red"> **DO NOT CHANGE ANYTHING IN THE CELL BELOW**

# %%
## DO NOT CHANGE THIS CELL
if RAW_FILE == r"YOUR FILEPATH HERE":
	raise Exception("You must update the RAW_FILE variable in the previous cell to match your local filepath.")
	
RAW_FILE
# Out:
# '/Users/ashik/Downloads/Crimes_-_2001_to_Present.csv'

# %%
## (Optional) SET THE FOLDER FOR FINAL FILES
OUTPUT_FOLDER = 'Data/Chicago/'
os.makedirs(OUTPUT_FOLDER, exist_ok=True)

# %% [markdown]
# # 🔄 Full Workflow

# %% [markdown]
# - Now that your RAW_FILE variable is set either:
#     - On the toolbar, click on the Kernel menu > "Restart and Run All".
#     - OR click on this cell first, then on the toolbar click on the "Cell" menu > "Run All Below"

# %%
import pandas as pd

chicago_full = pd.read_csv(RAW_FILE)
chicago_full
# Out:
#                ID Case Number                    Date  \
# 0        11037294    JA371270  03/18/2015 12:00:00 PM
# 1        11646293    JC213749  12/20/2018 03:00:00 PM
# 2        11645836    JC212333  05/01/2016 12:25:00 AM
# 3        11645959    JC211511  12/20/2018 04:00:00 PM
# 4        11645601    JC212935  06/01/2014 12:01:00 AM
# ...           ...         ...                     ...
# 7905373  12131776    JD327752  08/10/2020 08:30:00 PM
# 7905374  12082414    JD269218  06/18/2020 09:00:00 PM
# 7905375  12118237    JD311791  07/27/2020 03:02:00 PM
# 7905376  12142591    JD340297  08/14/2020 03:00:00 PM
# 7905377  12002171    JD177406  03/06/2020 02:00:00 PM
#
#                                        Block  IUCR         Primary Type  \
# 0                          0000X W WACKER DR  1153   DECEPTIVE PRACTICE
# 1                       023XX N LOCKWOOD AVE  1154   DECEPTIVE PRACTICE
# 2                        055XX S ROCKWELL ST  1153   DECEPTIVE PRACTICE
# 3                         045XX N ALBANY AVE  2820        OTHER OFFENSE
# 4                        087XX S SANGAMON ST  1153   DECEPTIVE PRACTICE
# ...                                      ...   ...                  ...
# 7905373               066XX S SACRAMENTO AVE  0620             BURGLARY
# 7905374  093XX S DR MARTIN LUTHER KING JR DR  0820                THEFT
# 7905375                      033XX W POLK ST  0486              BATTERY
# 7905376                 023XX W ROSEMONT AVE  0910  MOTOR VEHICLE THEFT
# 7905377                 033XX N LAKEWOOD AVE  1150   DECEPTIVE PRACTICE
#
#                                      Description Location Description  Arrest  \
# 0            FINANCIAL IDENTITY THEFT OVER $ 300                 BANK   False
# 1        FINANCIAL IDENTITY THEFT $300 AND UNDER            APARTMENT   False
# 2            FINANCIAL IDENTITY THEFT OVER $ 300                  NaN   False
# 3                               TELEPHONE THREAT            RESIDENCE   False
# 4            FINANCIAL IDENTITY THEFT OVER $ 300            RESIDENCE   False
# ...                                          ...                  ...     ...
# 7905373                           UNLAWFUL ENTRY            APARTMENT   False
# 7905374                           $500 AND UNDER            RESIDENCE   False
# 7905375                  DOMESTIC BATTERY SIMPLE            APARTMENT   False
# 7905376                               AUTOMOBILE               STREET   False
# 7905377                        CREDIT CARD FRAUD            APARTMENT   False
#
#          Domestic  ...  Ward  Community Area  FBI Code  X Coordinate  \
# 0           False  ...  42.0            32.0        11           NaN
# 1           False  ...  36.0            19.0        11           NaN
# 2           False  ...  15.0            63.0        11           NaN
# 3           False  ...  33.0            14.0       08A           NaN
# 4           False  ...  21.0            71.0        11           NaN
# ...           ...  ...   ...             ...       ...           ...
# 7905373     False  ...  17.0            66.0        05     1157527.0
# 7905374     False  ...   9.0            49.0        06     1180558.0
# 7905375      True  ...  24.0            27.0       08B     1154169.0
# 7905376     False  ...  50.0             2.0        07     1159419.0
# 7905377     False  ...  44.0             6.0        11     1167040.0
#
#         Y Coordinate  Year              Updated On   Latitude  Longitude  \
# 0                NaN  2015  08/01/2017 03:52:26 PM        NaN        NaN
# 1                NaN  2018  04/06/2019 04:04:43 PM        NaN        NaN
# 2                NaN  2016  04/06/2019 04:04:43 PM        NaN        NaN
# 3                NaN  2018  04/06/2019 04:04:43 PM        NaN        NaN
# 4                NaN  2014  04/06/2019 04:04:43 PM        NaN        NaN
# ...              ...   ...                     ...        ...        ...
# 7905373    1860392.0  2020  08/17/2020 03:41:32 PM  41.772671 -87.698104
# 7905374    1843036.0  2020  06/25/2020 03:41:40 PM  41.724546 -87.614211
# 7905375    1896171.0  2020  08/03/2020 03:41:51 PM  41.870921 -87.709461
# 7905376    1941765.0  2020  08/26/2020 03:40:41 PM  41.995927 -87.688929
# 7905377    1922212.0  2020  03/13/2020 03:41:29 PM  41.942112 -87.661459
#
#                               Location
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ...                                ...
# 7905373  (41.772671069, -87.698104059)
# 7905374  (41.724546436, -87.614210743)
# 7905375  (41.870920735, -87.709461362)
# 7905376  (41.995927389, -87.688928533)
# 7905377  (41.942112495, -87.661458579)
#
# [7905378 rows x 22 columns]

# %%
# this cell can take up to 1 min to run
date_format = "%m/%d/%Y %H:%M:%S %p"

chicago_full['Datetime'] = pd.to_datetime(chicago_full['Date'], format=date_format)
chicago_full = chicago_full.sort_values('Datetime')
chicago_full
# Out:
#                ID Case Number                    Date                   Block  \
# 2236505   1311358     G001819  01/01/2001 01:00:00 PM           025XX W 45 PL
# 2157232   1325760     G001074  01/01/2001 01:00:00 PM   029XX S CALIFORNIA AV
# 2230119   1333483     G032501  01/01/2001 01:00:00 PM          025XX W 119 ST
# 2157743   1311049     G000125  01/01/2001 01:00:00 AM  032XX W IRVING PARK RD
# 2217322   1410662     G123231  01/01/2001 01:00:00 AM           007XX E 50 PL
# ...           ...         ...                     ...                     ...
# 106141   13225412    JG441845  09/28/2023 12:00:00 AM    115XX S ELIZABETH ST
# 106662   13225510    JG441991  09/28/2023 12:00:00 AM  060XX S MARSHFIELD AVE
# 106135   13225566    JG442054  09/28/2023 12:00:00 AM   051XX S MAPLEWOOD AVE
# 106646   13227468    JG444323  09/28/2023 12:00:00 AM         014XX E 65TH ST
# 106383   13226082    JG442729  09/28/2023 12:00:00 AM      086XX S HOLLAND RD
#
#          IUCR         Primary Type                   Description  \
# 2236505  0610             BURGLARY                FORCIBLE ENTRY
# 2157232  1811            NARCOTICS  POSS: CANNABIS 30GMS OR LESS
# 2230119  1320      CRIMINAL DAMAGE                    TO VEHICLE
# 2157743  1310      CRIMINAL DAMAGE                   TO PROPERTY
# 2217322  0560              ASSAULT                        SIMPLE
# ...       ...                  ...                           ...
# 106141   1310      CRIMINAL DAMAGE                   TO PROPERTY
# 106662   0910  MOTOR VEHICLE THEFT                    AUTOMOBILE
# 106135   0910  MOTOR VEHICLE THEFT                    AUTOMOBILE
# 106646   0820                THEFT                $500 AND UNDER
# 106383   0820                THEFT                $500 AND UNDER
#
#                  Location Description  Arrest  Domestic  ...  Community Area  \
# 2236505                     RESIDENCE   False     False  ...             NaN
# 2157232  GOVERNMENT BUILDING/PROPERTY    True     False  ...             NaN
# 2230119                        STREET   False     False  ...             NaN
# 2157743                         OTHER   False     False  ...             NaN
# 2217322                     RESIDENCE   False      True  ...             NaN
# ...                               ...     ...       ...  ...             ...
# 106141                      RESIDENCE   False      True  ...            53.0
# 106662                         STREET   False     False  ...            67.0
# 106135                         STREET   False     False  ...            63.0
# 106646                      APARTMENT   False     False  ...            42.0
# 106383              CONSTRUCTION SITE    True     False  ...            44.0
#
#          FBI Code  X Coordinate  Y Coordinate  Year              Updated On  \
# 2236505        05     1160341.0     1874463.0  2001  08/17/2015 03:03:40 PM
# 2157232        18           NaN           NaN  2001  08/17/2015 03:03:40 PM
# 2230119        14     1161850.0     1825696.0  2001  08/17/2015 03:03:40 PM
# 2157743        14     1153841.0     1926448.0  2001  08/17/2015 03:03:40 PM
# 2217322       08A     1181985.0     1871730.0  2001  08/17/2015 03:03:40 PM
# ...           ...           ...           ...   ...                     ...
# 106141         14     1170068.0     1828215.0  2023  10/05/2023 03:43:05 PM
# 106662         07     1166375.0     1864646.0  2023  10/05/2023 03:43:05 PM
# 106135         07     1160240.0     1870508.0  2023  10/05/2023 03:43:05 PM
# 106646         06     1186932.0     1862181.0  2023  10/05/2023 03:43:05 PM
# 106383         06     1175576.0     1847532.0  2023  10/05/2023 03:43:05 PM
#
#           Latitude  Longitude                       Location  \
# 2236505  41.811226 -87.687401  (41.811226273, -87.687401084)
# 2157232        NaN        NaN                            NaN
# 2230119  41.677371 -87.683218  (41.677370879, -87.683217554)
# 2157743  41.954010 -87.709858  (41.954010014, -87.709857541)
# 2217322  41.803253 -87.608098  (41.803252854, -87.608097536)
# ...            ...        ...                            ...
# 106141   41.684109 -87.653064  (41.684109346, -87.653064253)
# 106662   41.784161 -87.665548  (41.784160675, -87.665548482)
# 106135   41.800375 -87.687880   (41.800375333, -87.68788049)
# 106646   41.776934 -87.590257  (41.776933681, -87.590257484)
# 106383   41.736997 -87.632326  (41.736996809, -87.632325526)
#
#                    Datetime
# 2236505 2001-01-01 01:00:00
# 2157232 2001-01-01 01:00:00
# 2230119 2001-01-01 01:00:00
# 2157743 2001-01-01 01:00:00
# 2217322 2001-01-01 01:00:00
# ...                     ...
# 106141  2023-09-28 12:00:00
# 106662  2023-09-28 12:00:00
# 106135  2023-09-28 12:00:00
# 106646  2023-09-28 12:00:00
# 106383  2023-09-28 12:00:00
#
# [7905378 rows x 23 columns]

# %% [markdown]
# ## Separate the Full Dataset by Years

# %%
chicago_full['Datetime'].dt.year
# Out:
# 2236505    2001
# 2157232    2001
# 2230119    2001
# 2157743    2001
# 2217322    2001
#            ...
# 106141     2023
# 106662     2023
# 106135     2023
# 106646     2023
# 106383     2023
# Name: Datetime, Length: 7905378, dtype: int64

# %%
# save the years for every crime
chicago_full["Year"] = chicago_full['Datetime'].dt.year.astype(str)
chicago_full["Year"].value_counts()
# Out:
# 2002    486808
# 2001    485889
# 2003    475985
# 2004    469423
# 2005    453775
# 2006    448178
# 2007    437090
# 2008    427184
# 2009    392827
# 2010    370517
# 2011    351993
# 2012    336324
# 2013    307541
# 2014    275794
# 2016    269834
# 2017    269108
# 2018    268917
# 2015    264798
# 2019    261356
# 2022    238978
# 2020    212224
# 2021    208884
# 2023    191951
# Name: Year, dtype: int64

# %%
## Dropping unneeded columns to reduce file size
drop_cols = ["X Coordinate","Y Coordinate", "Community Area","FBI Code",
             "Case Number","Updated On",'Block','Location','IUCR']

# %%
# save final df
chicago_final = chicago_full.drop(columns=drop_cols)
chicago_final = chicago_final.set_index('Datetime')
chicago_final
# Out:
#                            ID                    Date         Primary Type  \
# Datetime
# 2001-01-01 01:00:00   1311358  01/01/2001 01:00:00 PM             BURGLARY
# 2001-01-01 01:00:00   1325760  01/01/2001 01:00:00 PM            NARCOTICS
# 2001-01-01 01:00:00   1333483  01/01/2001 01:00:00 PM      CRIMINAL DAMAGE
# 2001-01-01 01:00:00   1311049  01/01/2001 01:00:00 AM      CRIMINAL DAMAGE
# 2001-01-01 01:00:00   1410662  01/01/2001 01:00:00 AM              ASSAULT
# ...                       ...                     ...                  ...
# 2023-09-28 12:00:00  13225412  09/28/2023 12:00:00 AM      CRIMINAL DAMAGE
# 2023-09-28 12:00:00  13225510  09/28/2023 12:00:00 AM  MOTOR VEHICLE THEFT
# 2023-09-28 12:00:00  13225566  09/28/2023 12:00:00 AM  MOTOR VEHICLE THEFT
# 2023-09-28 12:00:00  13227468  09/28/2023 12:00:00 AM                THEFT
# 2023-09-28 12:00:00  13226082  09/28/2023 12:00:00 AM                THEFT
#
#                                       Description  \
# Datetime
# 2001-01-01 01:00:00                FORCIBLE ENTRY
# 2001-01-01 01:00:00  POSS: CANNABIS 30GMS OR LESS
# 2001-01-01 01:00:00                    TO VEHICLE
# 2001-01-01 01:00:00                   TO PROPERTY
# 2001-01-01 01:00:00                        SIMPLE
# ...                                           ...
# 2023-09-28 12:00:00                   TO PROPERTY
# 2023-09-28 12:00:00                    AUTOMOBILE
# 2023-09-28 12:00:00                    AUTOMOBILE
# 2023-09-28 12:00:00                $500 AND UNDER
# 2023-09-28 12:00:00                $500 AND UNDER
#
#                              Location Description  Arrest  Domestic  Beat  \
# Datetime
# 2001-01-01 01:00:00                     RESIDENCE   False     False   914
# 2001-01-01 01:00:00  GOVERNMENT BUILDING/PROPERTY    True     False  1033
# 2001-01-01 01:00:00                        STREET   False     False  2212
# 2001-01-01 01:00:00                         OTHER   False     False  1724
# 2001-01-01 01:00:00                     RESIDENCE   False      True   223
# ...                                           ...     ...       ...   ...
# 2023-09-28 12:00:00                     RESIDENCE   False      True   524
# 2023-09-28 12:00:00                        STREET   False     False   714
# 2023-09-28 12:00:00                        STREET   False     False   923
# 2023-09-28 12:00:00                     APARTMENT   False     False   321
# 2023-09-28 12:00:00             CONSTRUCTION SITE    True     False   622
#
#                      District  Ward  Year   Latitude  Longitude
# Datetime
# 2001-01-01 01:00:00       9.0   NaN  2001  41.811226 -87.687401
# 2001-01-01 01:00:00      10.0   NaN  2001        NaN        NaN
# 2001-01-01 01:00:00      22.0   NaN  2001  41.677371 -87.683218
# 2001-01-01 01:00:00      17.0   NaN  2001  41.954010 -87.709858
# 2001-01-01 01:00:00       2.0   NaN  2001  41.803253 -87.608098
# ...                       ...   ...   ...        ...        ...
# 2023-09-28 12:00:00       5.0  21.0  2023  41.684109 -87.653064
# 2023-09-28 12:00:00       7.0  15.0  2023  41.784161 -87.665548
# 2023-09-28 12:00:00       9.0  14.0  2023  41.800375 -87.687880
# 2023-09-28 12:00:00       3.0   5.0  2023  41.776934 -87.590257
# 2023-09-28 12:00:00       6.0  21.0  2023  41.736997 -87.632326
#
# [7905378 rows x 13 columns]

# %%
# unique # of year bins
year_bins = chicago_final['Year'].astype(str).unique()
year_bins
# Out:
# array(['2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008',
#        '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
#        '2017', '2018', '2019', '2020', '2021', '2022', '2023'],
#       dtype=object)

# %%
FINAL_DROP = ['Year']

# %%
## set save location 

os.makedirs(OUTPUT_FOLDER, exist_ok=True)
print(f"[i] Saving .csv's to {OUTPUT_FOLDER}")
## loop through years
for year in year_bins:
    
    ## save temp slices of dfs to save.
    temp_df = chicago_final.loc[year]
    temp_df = temp_df.sort_index()
    temp_df = temp_df.reset_index(drop=True)
    temp_df = temp_df.drop(columns=FINAL_DROP)

    # save as csv to output folder
    fname_temp = f"{OUTPUT_FOLDER}Chicago-Crime_{year}.csv"#.gz
    temp_df.to_csv(fname_temp,index=False)

    print(f"- Succesfully saved {fname_temp}")
# Out:
# [i] Saving .csv's to Data/Chicago/
# - Succesfully saved Data/Chicago/Chicago-Crime_2001.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2002.csv
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In [17], line 16
#      14 # save as csv to output folder
#      15 fname_temp = f"{OUTPUT_FOLDER}Chicago-Crime_{year}.csv"#.gz
# ---> 16 temp_df.to_csv(fname_temp,index=False)
#      18 print(f"- Succesfully saved {fname_temp}")
#
# File ~/anaconda3/envs/dojo-env/lib/python3.9/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/dojo-env/lib/python3.9/site-packages/pandas/core/generic.py:3720, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3709 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3711 formatter = DataFrameFormatter(
#    3712     frame=df,
#    3713     header=header,
#    (...)
#    3717     decimal=decimal,
#    3718 )
# -> 3720 return DataFrameRenderer(formatter).to_csv(
#    3721     path_or_buf,
#    3722     lineterminator=lineterminator,
#    3723     sep=sep,
#    3724     encoding=encoding,
#    3725     errors=errors,
#    3726     compression=compression,
#    3727     quoting=quoting,
#    3728     columns=columns,
#    3729     index_label=index_label,
#    3730     mode=mode,
#    3731     chunksize=chunksize,
#    3732     quotechar=quotechar,
#    3733     date_format=date_format,
#    3734     doublequote=doublequote,
#    3735     escapechar=escapechar,
#    3736     storage_options=storage_options,
#    3737 )
#
# File ~/anaconda3/envs/dojo-env/lib/python3.9/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/dojo-env/lib/python3.9/site-packages/pandas/io/formats/format.py:1189, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1168     created_buffer = False
#    1170 csv_formatter = CSVFormatter(
#    1171     path_or_buf=path_or_buf,
#    1172     lineterminator=lineterminator,
#    (...)
#    1187     formatter=self.fmt,
#    1188 )
# -> 1189 csv_formatter.save()
#    1191 if created_buffer:
#    1192     assert isinstance(path_or_buf, StringIO)
#
# File ~/anaconda3/envs/dojo-env/lib/python3.9/site-packages/pandas/io/formats/csvs.py:261, in CSVFormatter.save(self)
#     241 with get_handle(
#     242     self.filepath_or_buffer,
#     243     self.mode,
#    (...)
#     249
#     250     # Note: self.encoding is irrelevant here
#     251     self.writer = csvlib.writer(
#     252         handles.handle,
#     253         lineterminator=self.lineterminator,
#    (...)
#     258         quotechar=self.quotechar,
#     259     )
# --> 261     self._save()
#
# File ~/anaconda3/envs/dojo-env/lib/python3.9/site-packages/pandas/io/formats/csvs.py:266, in CSVFormatter._save(self)
#     264 if self._need_to_save_header:
#     265     self._save_header()
# --> 266 self._save_body()
#
# File ~/anaconda3/envs/dojo-env/lib/python3.9/site-packages/pandas/io/formats/csvs.py:304, in CSVFormatter._save_body(self)
#     302 if start_i >= end_i:
#     303     break
# --> 304 self._save_chunk(start_i, end_i)
#
# File ~/anaconda3/envs/dojo-env/lib/python3.9/site-packages/pandas/io/formats/csvs.py:315, in CSVFormatter._save_chunk(self, start_i, end_i)
#     312 data = [res.iget_values(i) for i in range(len(res.items))]
#     314 ix = self.data_index[slicer]._format_native_types(**self._number_format)
# --> 315 libwriters.write_csv_rows(
#     316     data,
#     317     ix,
#     318     self.nlevels,
#     319     self.cols,
#     320     self.writer,
#     321 )
#
# File ~/anaconda3/envs/dojo-env/lib/python3.9/site-packages/pandas/_libs/writers.pyx:72, in pandas._libs.writers.write_csv_rows()
#
# OSError: [Errno 28] No space left on device

# %%
saved_files = sorted(glob.glob(OUTPUT_FOLDER+'*.*csv'))
saved_files
# Out:
# ['Data/Chicago/Chicago-Crime_2001.csv',
#  'Data/Chicago/Chicago-Crime_2002.csv',
#  'Data/Chicago/Chicago-Crime_2003.csv']

# %%
## create a README.txt for the zip files
readme = """Source URL: 
- https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-Present/ijzp-q8t2
- Filtered for years 2000-Present.

Downloaded 07/18/2022
- Files are split into 1 year per file.

EXAMPLE USAGE:
>> import glob
>> import pandas as pd
>> folder = "Data/Chicago/"
>> crime_files = sorted(glob.glob(folder+"*.csv"))
>> df = pd.concat([pd.read_csv(f) for f in crime_files])
"""
print(readme)


with open(f"{OUTPUT_FOLDER}README.txt",'w') as f:
    f.write(readme)
# Out:
# Source URL:
# - https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-Present/ijzp-q8t2
# - Filtered for years 2000-Present.
#
# Downloaded 07/18/2022
# - Files are split into 1 year per file.
#
# EXAMPLE USAGE:
# >> import glob
# >> import pandas as pd
# >> folder = "Data/Chicago/"
# >> crime_files = sorted(glob.glob(folder+"*.csv"))
# >> df = pd.concat([pd.read_csv(f) for f in crime_files])

# %% [markdown]
# ## Confirmation

# %% [markdown]
# - Follow the example usage above to test if your files were created successfully.

# %%
# get list of files from folder
crime_files = sorted(glob.glob(OUTPUT_FOLDER+"*.csv"))
df = pd.concat([pd.read_csv(f, nrows=5) for f in crime_files])
df
# Out:
#         ID                    Date                Primary Type  \
# 0  1311358  01/01/2001 01:00:00 PM                    BURGLARY
# 1  1325760  01/01/2001 01:00:00 PM                   NARCOTICS
# 2  1333483  01/01/2001 01:00:00 PM             CRIMINAL DAMAGE
# 3  1311049  01/01/2001 01:00:00 AM             CRIMINAL DAMAGE
# 4  1410662  01/01/2001 01:00:00 AM                     ASSAULT
# 0  1920530  01/01/2002 01:00:00 PM                       THEFT
# 1  1919739  01/01/2002 01:00:00 PM         MOTOR VEHICLE THEFT
# 2  7582838  01/01/2002 01:00:00 AM  OFFENSE INVOLVING CHILDREN
# 3  1937090  01/01/2002 01:00:00 PM                     BATTERY
# 4  3679782  01/01/2002 01:00:00 PM                       THEFT
# 0  2522395  01/01/2003 01:00:00 AM                       THEFT
# 1  3116714  01/01/2003 01:00:00 PM               OTHER OFFENSE
# 2  2523280  01/01/2003 01:00:00 AM           WEAPONS VIOLATION
# 3  2525840  01/01/2003 01:00:00 AM                     ASSAULT
# 4  2523382  01/01/2003 01:00:00 AM                       THEFT
#
#                       Description          Location Description  Arrest  \
# 0                  FORCIBLE ENTRY                     RESIDENCE   False
# 1    POSS: CANNABIS 30GMS OR LESS  GOVERNMENT BUILDING/PROPERTY    True
# 2                      TO VEHICLE                        STREET   False
# 3                     TO PROPERTY                         OTHER   False
# 4                          SIMPLE                     RESIDENCE   False
# 0                  $500 AND UNDER                        STREET   False
# 1                      AUTOMOBILE                        STREET   False
# 2    CRIM SEX ABUSE BY FAM MEMBER                     RESIDENCE   False
# 3                          SIMPLE                      SIDEWALK   False
# 4  FINANCIAL ID THEFT:$300 &UNDER                     RESIDENCE   False
# 0                  $500 AND UNDER                        STREET   False
# 1                 ANIMAL FIGHTING                        STREET   False
# 2        UNLAWFUL POSS OF HANDGUN                         ALLEY    True
# 3                          SIMPLE                     RESIDENCE   False
# 4                  POCKET-PICKING           TAVERN/LIQUOR STORE   False
#
#    Domestic  Beat  District  Ward   Latitude  Longitude
# 0     False   914       9.0   NaN  41.811226 -87.687401
# 1     False  1033      10.0   NaN        NaN        NaN
# 2     False  2212      22.0   NaN  41.677371 -87.683218
# 3     False  1724      17.0   NaN  41.954010 -87.709858
# 4      True   223       2.0   NaN  41.803253 -87.608098
# 0     False   434       4.0   NaN        NaN        NaN
# 1     False  1132      11.0   NaN  41.872558 -87.723662
# 2      True   223       2.0   3.0        NaN        NaN
# 3     False   732       7.0   NaN  41.766270 -87.635958
# 4     False  1633      16.0  38.0  41.952062 -87.780041
# 0     False   414       4.0   8.0  41.747100 -87.573466
# 1     False   915       9.0  16.0  41.795304 -87.674341
# 2     False   914       9.0  20.0  41.809498 -87.673502
# 3      True   722       7.0   6.0  41.771595 -87.638702
# 4     False  1933      19.0  43.0  41.925764 -87.649210

# %%
years = df['Date'].map(lambda x: x.split()[0].split('/')[-1])
years.value_counts().sort_index()
# Out:
# 2001    5
# 2002    5
# 2003    5
# Name: Date, dtype: int64

# %% [markdown]
# ## Summary

# %% [markdown]
# - The chicago crime dataset has now been saved to your repository as csv files.
# - You should save your notebook, commit your work and push to GitHub using GitHub desktop.

# %%
chicago_final.head()
# Out:
#                           ID                    Date     Primary Type  \
# Datetime
# 2001-01-01 01:00:00  1311358  01/01/2001 01:00:00 PM         BURGLARY
# 2001-01-01 01:00:00  1325760  01/01/2001 01:00:00 PM        NARCOTICS
# 2001-01-01 01:00:00  1333483  01/01/2001 01:00:00 PM  CRIMINAL DAMAGE
# 2001-01-01 01:00:00  1311049  01/01/2001 01:00:00 AM  CRIMINAL DAMAGE
# 2001-01-01 01:00:00  1410662  01/01/2001 01:00:00 AM          ASSAULT
#
#                                       Description  \
# Datetime
# 2001-01-01 01:00:00                FORCIBLE ENTRY
# 2001-01-01 01:00:00  POSS: CANNABIS 30GMS OR LESS
# 2001-01-01 01:00:00                    TO VEHICLE
# 2001-01-01 01:00:00                   TO PROPERTY
# 2001-01-01 01:00:00                        SIMPLE
#
#                              Location Description  Arrest  Domestic  Beat  \
# Datetime
# 2001-01-01 01:00:00                     RESIDENCE   False     False   914
# 2001-01-01 01:00:00  GOVERNMENT BUILDING/PROPERTY    True     False  1033
# 2001-01-01 01:00:00                        STREET   False     False  2212
# 2001-01-01 01:00:00                         OTHER   False     False  1724
# 2001-01-01 01:00:00                     RESIDENCE   False      True   223
#
#                      District  Ward  Year   Latitude  Longitude
# Datetime
# 2001-01-01 01:00:00       9.0   NaN  2001  41.811226 -87.687401
# 2001-01-01 01:00:00      10.0   NaN  2001        NaN        NaN
# 2001-01-01 01:00:00      22.0   NaN  2001  41.677371 -87.683218
# 2001-01-01 01:00:00      17.0   NaN  2001  41.954010 -87.709858
# 2001-01-01 01:00:00       2.0   NaN  2001  41.803253 -87.608098

# %%
chicago_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7905378 entries, 2236505 to 106383
# Data columns (total 23 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   ID                    int64
#  1   Case Number           object
#  2   Date                  object
#  3   Block                 object
#  4   IUCR                  object
#  5   Primary Type          object
#  6   Description           object
#  7   Location Description  object
#  8   Arrest                bool
#  9   Domestic              bool
#  10  Beat                  int64
#  11  District              float64
#  12  Ward                  float64
#  13  Community Area        float64
#  14  FBI Code              object
#  15  X Coordinate          float64
#  16  Y Coordinate          float64
#  17  Year                  object
#  18  Updated On            object
#  19  Latitude              float64
#  20  Longitude             float64
#  21  Location              object
#  22  Datetime              datetime64[ns]
# dtypes: bool(2), datetime64[ns](1), float64(7), int64(2), object(11)
# memory usage: 1.3+ GB

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import datetime as dt
import matplotlib.ticker as mticks
import matplotlib.dates as mdates

# %% [markdown]
# #  Topic 1) Comparing Police Districts:
# Which district has the most crimes? Which has the least?

# %%
district_most_crimes = chicago_final['District'].value_counts().idxmax()
district_most_crimes
# Out:
# 8.0

# %%
district_least_crimes = chicago_final['District'].value_counts().idxmin()
district_least_crimes

least_crime_count = district_most_crimes.min()

# %%
print(f"District with most crimes: District {district_most_crimes} ")
print(f"District with least crimes: District {low_crime_district} )")
# Out:
# District with most crimes: District 8.0
# District with least crimes: District 21.0 )

# %% [markdown]
# # Topic 2) Crimes Across the Years:

# %%
# Convert Year column to datetime
chicago_full['Year'] = pd.to_datetime(chicago_full['Year'], format='%Y')

# total number of crimes per year
total_crimes_yearly = chicago_full.resample('Y', on='Year').size()

# Plot 
plt.figure(figsize=(10, 6))
total_crimes_yearly.plot(kind='line')
plt.title('Total Number of Crimes Across the Years')
plt.xlabel('Year')
plt.ylabel('Number of Crimes')
plt.show()

# %% [markdown]
# The number of crimes have greatly decreased through the years.

# %%
resampled_df = chicago_final.copy()
resampled_df['Month Name'] = resampled_df.index.month_name()
resampled_df.head()
# Out:
#                           ID                    Date     Primary Type  \
# Datetime
# 2001-01-01 01:00:00  1311358  01/01/2001 01:00:00 PM         BURGLARY
# 2001-01-01 01:00:00  1325760  01/01/2001 01:00:00 PM        NARCOTICS
# 2001-01-01 01:00:00  1333483  01/01/2001 01:00:00 PM  CRIMINAL DAMAGE
# 2001-01-01 01:00:00  1311049  01/01/2001 01:00:00 AM  CRIMINAL DAMAGE
# 2001-01-01 01:00:00  1410662  01/01/2001 01:00:00 AM          ASSAULT
#
#                                       Description  \
# Datetime
# 2001-01-01 01:00:00                FORCIBLE ENTRY
# 2001-01-01 01:00:00  POSS: CANNABIS 30GMS OR LESS
# 2001-01-01 01:00:00                    TO VEHICLE
# 2001-01-01 01:00:00                   TO PROPERTY
# 2001-01-01 01:00:00                        SIMPLE
#
#                              Location Description  Arrest  Domestic  Beat  \
# Datetime
# 2001-01-01 01:00:00                     RESIDENCE   False     False   914
# 2001-01-01 01:00:00  GOVERNMENT BUILDING/PROPERTY    True     False  1033
# 2001-01-01 01:00:00                        STREET   False     False  2212
# 2001-01-01 01:00:00                         OTHER   False     False  1724
# 2001-01-01 01:00:00                     RESIDENCE   False      True   223
#
#                      District  Ward  Year   Latitude  Longitude Month Name
# Datetime
# 2001-01-01 01:00:00       9.0   NaN  2001  41.811226 -87.687401    January
# 2001-01-01 01:00:00      10.0   NaN  2001        NaN        NaN    January
# 2001-01-01 01:00:00      22.0   NaN  2001  41.677371 -87.683218    January
# 2001-01-01 01:00:00      17.0   NaN  2001  41.954010 -87.709858    January
# 2001-01-01 01:00:00       2.0   NaN  2001  41.803253 -87.608098    January

# %%
ax = sns.countplot(data=resampled_df, x='Month Name')

# plot
plt.title('Number of Crimes by Month')
plt.xlabel('Month')
plt.ylabel('Number of Crimes')
plt.xticks(rotation=45)  

plt.show()

# %% [markdown]
# July has the most crimes by month.

# %% [markdown]
# # Topic 4) Comparing Months:
# What months have the most crime? What months have the least?
# Are there any individual crimes that do not follow this pattern? If so, which crimes?

# %%
chicago_full['Date'] = pd.to_datetime(chicago_full['Date'], format='%m/%d/%Y %I:%M:%S %p')

# total number of crimes per month
total_crimes_monthly = chicago_full.resample('M', on='Date').size()

# month with the most and least crimes
month_most_crimes = total_crimes_monthly.idxmax().strftime('%B')
month_least_crimes = total_crimes_monthly.idxmin().strftime('%B')

# Get the counts for the most and least crimes
most_crimes_count = total_crimes_monthly.max()
least_crimes_count = total_crimes_monthly.min()

# %%
print(f"Month with most crimes is {month_most_crimes} at {most_crimes_count} counts.")
print(f"Month with least crimes is {month_least_crimes} at {least_crimes_count} counts.")
# Out:
# Month with most crimes is July at 46013 counts.
# Month with least crimes is April at 12923 counts.
